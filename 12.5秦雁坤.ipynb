# %%
from tkinter import*
from tkinter import ttk

# %%
#graphical user interface
def on_click():
    print('hello')
button=ttk.Button()
button.pack()
button['text']='Click me!'
button['command']=on_click
mainloop()

# %%
for i in range(10):
    ttk.Button(text=i).pack(fill=BOTH,expand=True)

mainloop()

# %%
for i in range(10):
    ttk.Button(text=i).pack(side=LEFT,fill=BOTH,expand=True)

mainloop()

# %%
def on_click():
    label['text']='clicked'
label=ttk.Label(text='hello')
label.pack()

button=ttk.Button()
button.pack()
button['text']='Click me!'
button['command']=on_click
                
mainloop()

# %%
for i in range(4):
    for j in range(5):
        text='{}.{}'.format(i,j)
        ttk.Button(text=text).grid(row=i,column=j)
        
mainloop()

# %%
from tkinter import*
from tkinter import ttk

class Calculator(Tk):
    def __init__(self,*args,**kwargs):
        super().__init__(self,*args,**kwargs)
        self.title('Simple calculator')
        self.geometry('400*600')
        
        self.result_

        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)

        for i in range(4):
            ttk.Button(row,text=i).pack(side=LEFT,expand=True,fill=BOTH)
        
        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)
        for i in range(4):
            ttk.Button(row,text=i).pack(side=LEFT,expand=True,fill=BOTH)
if __name__=="__main__":
    app=Calculator()
    app.mainloop()
# Out:
#   File "<ipython-input-19-d7a861ea70de>", line 5
#     def__init__(self,*args,**kwargs):
#                                      ^
# SyntaxError: invalid syntax

# %%
from tkinter import*
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated=0
    in_number1=1
    post_operator=2
    in_number2=3

class Calculator(Tk):
    def __init__(self,*args,**kwargs):
        super().__init__(self,*args,**kwargs)
        self.title('Simple calculator')
        self.geometry('400*600')
            
        self.result_string=StringVar()
        self.result_string.set('0')
        self.number1='0'
        self.number2=None
        self.operator=None
        self.state=State.calculated
        
        
        #output
        output=ttk.Label(self,textvariable=self.result_string,font=('TKDEfaulFont',48),anchor=E)
        output.pack(side=TOP,expand=True,fill=BOTH)
        #row1
        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)
        self.add_button(row,'CE',self.on_ce_click)
        self.add_button(row,'C',self.on_c_click)
        self.add_button(row,'Back',self.on_Back_click)
        self.add_button(row,'/',self.on_division_click)
        
        #row2
        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)
        self.add_button(row,'7',self.gen_on_number_click('7'))
        self.add_button(row,'8',self.gen_on_number_click('8'))
        self.add_button(row,'9',self.gen_on_number_click('9'))
        self.add_button(row,'x',self.on_multiply_click)
        
         #row3
        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)
        self.add_button(row,'4',gen_on_number_click('4'))
        self.add_button(row,'5',gen_on_number_click('5'))
        self.add_button(row,'6',gen_on_number_click('6'))
        self.add_button(row,'-',self.on_minus_click)
        
         #row4
        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)
        self.add_button(row,'1',gen_on_number_click('1'))
        self.add_button(row,'2',gen_on_number_click('2'))
        self.add_button(row,'3',gen_on_number_click('3'))
        self.add_button(row,'+',self.on_add_click)
        
         #row5
        row=Frame(self)
        row.pack(side=TOP,expand=True,fill=BOTH)
        self.add_button(row,'+/-',self.on_negative_click)
        self.add_button(row,'0',self.on_number_click('0'))
        self.add_button(row,'.',self.on_number_click('.'))
        self.add_button(row,'=',self.on_equal_click)
        
    def add_Button(self,parent,text=None,command=None):
        button=ttk.Button(parent,text=text,command=command)
        button.pack(side=LEFT,expand=True,fill=BOTH)
       
        
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_Back_click(self):
        print('Back clicked')
        
    def on_division_click(self):
        self.on_operator('/')
        print('division clicked')
   
    
        
    def on_multiply_click(self):
        self.on_operator('x')
        print('x clicked')
  
   
    def on_minus_click(self):
        print('- clicked')
        self.on_operator('-')
                                   
    def on_add_click(self):
        print('+ clicked')
        self.on_operator('+')
                                           
    def on_negative_click(self):
        print('+/- clicked')
                                                   
    #def on_0_click(self):
     #   self.on_number('0')
      #  print('0 clicked')
        
                                                   
   # def on_dot_click(self):
    #    print('. clicked')
     #   self.on_number('.')
                                                   
    def on_equal_click(self):
        print('= clicked')
        if self.operator=='+':
            self.number1=str(float(self.number1)+float(self.number2))
        elif self.operator=='-':
            self.number1=str(float(self.number1)-float(self.number2))
        elif self.operator=='*':
            self.number1=str(float(self.number1)*float(self.number2))  
        elif self.operator=='/':
            self.number1=str(float(self.number1)/float(self.number2))
            
        self.result_string.set(self.number1)
        self.state=State.calculated
        
    def on_number(self,ch):
        if self.state==State.calculated:
            self.number1=ch
            self.state=State.in_number1
        elif self.state==State.in_number1:
            self.number1=self.number1+ch
            self.result_string.set(self.number1)
        elif self.state==State.post_operator:
            self.number2=ch
            self.state=State.in_number2
            self.result_string.set(self.number2)
        elif self.state==State.in_number2:
            self.number2=self.number2+ch
            self.result_string.set(self.number2)
        # elif:assert(0)
            
    def on_operator(self,op):
        if self.state==State.calculated:
            self.state=State.post_operator
        elif self.state==State.in_number1:
            self.state=State.post_operator
        elif self.state==State.in_number2:
            self.on_equal_click()
            self.state=State.post_operator
        #elif:assert(0)
        self.operator=operator  
        
    def gen_on_number_click(self,ch):
        return lambda:self.on_number(ch)
   
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-588a81207e80> in <module>()
#     157
#     158 if __name__=='__main__':
# --> 159     app = Calculator()
#     160     app.mainloop()
#     161
#
# <ipython-input-7-588a81207e80> in __init__(self, *args, **kwargs)
#      11 class Calculator(Tk):
#      12     def __init__(self,*args,**kwargs):
# ---> 13         super().__init__(self,*args,**kwargs)
#      14         self.title('Simple calculator')
#      15         self.geometry('400*600')
#
# ~\Anaconda3\lib\tkinter\__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2018                 baseName = baseName + ext
#    2019         interactive = 0
# -> 2020         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2021         if useTk:
#    2022             self._loadtk()
#
# TypeError: create() argument 1 must be str or None, not Calculator
